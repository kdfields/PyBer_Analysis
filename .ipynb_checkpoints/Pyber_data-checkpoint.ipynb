# %%
# Add magic command to make sure plot fits
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics as st

# %%
# Read CSV file into dataframe
df = pd.read_csv("Resources/PyBer_ride_data.csv")
df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
# Set x-axis and tick locations.
# First, we need an array that is the length of the DataFrame. This will allow us to plot each month for each value 
# in the array. With the NumPy module, we create an array of numbers using the arange function for the df
x_axis = np.arange(len(df))

# Then we set the tick locations for every value, or month, in the x-axis using list comprehension.
tick_locations = [value for value in x_axis]

# Label x & y axes
# We add the xticks() function and pass in the tick_locations and the labels of the x-ticks, df["Month"].
df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, df["Month"])
# Out:
# ([<matplotlib.axis.XTick at 0x1aa001f6730>,
# ...
#  [Text(0, 0, 'Jan'),
#   Text(1, 0, 'Feb'),
#   Text(2, 0, 'Mar'),
#   Text(3, 0, 'April'),
#   Text(4, 0, 'May'),
#   Text(5, 0, 'June'),
#   Text(6, 0, 'July'),
#   Text(7, 0, 'Aug'),
#   Text(8, 0, 'Sept'),
#   Text(9, 0, 'Oct'),
#   Text(10, 0, 'Nov'),
#   Text(11, 0, 'Dec')])

# %%
# Set x-axis and tick locations.
# First, we need an array that is the length of the DataFrame. This will allow us to plot each month for each value 
# in the array. With the NumPy module, we create an array of numbers using the arange function for the df
x_axis = np.arange(len(df))

# Then we set the tick locations for every value, or month, in the x-axis using list comprehension.
tick_locations = [value for value in x_axis]

# Label x & y axes
# We add the xticks() function and pass in the tick_locations and the labels of the x-ticks, df["Month"].
df.plot.bar(x="Month", y="Avg. Fare ($USD)", color="r")
plt.xticks(tick_locations, df["Month"])
# Out:
# ([<matplotlib.axis.XTick at 0x1aa01c42b20>,
# ...
#  [Text(0, 0, 'Jan'),
#   Text(1, 0, 'Feb'),
#   Text(2, 0, 'Mar'),
#   Text(3, 0, 'April'),
#   Text(4, 0, 'May'),
#   Text(5, 0, 'June'),
#   Text(6, 0, 'July'),
#   Text(7, 0, 'Aug'),
#   Text(8, 0, 'Sept'),
#   Text(9, 0, 'Oct'),
#   Text(10, 0, 'Nov'),
#   Text(11, 0, 'Dec')])

# %%
##5.1.10 SKILL DRILL

# Set x-axis and tick locations.
# First, we need an array that is the length of the DataFrame. This will allow us to plot each month for each value 
# in the array. With the NumPy module, we create an array of numbers using the arange function for the df
x_axis = np.arange(len(df))

# Then we set the tick locations for every value, or month, in the x-axis using list comprehension.
tick_locations = [value for value in x_axis]

# Found stdev of "Avg. Fare ($USD)" column for errorbars
stdev = df["Avg. Fare ($USD)"].std()

# Label x & y axes
# Turn linegraph into bargraph
# Add stdev, color, and capsize
# Changed rotation of ticks to 90
# We add the xticks() function and pass in the tick_locations and the labels of the x-ticks, df["Month"].
df.plot.bar(x="Month", y="Avg. Fare ($USD)", yerr=stdev, color="lightblue", capsize=3)
plt.xticks(tick_locations, df["Month"], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1aa0216f100>,
# ...
#  [Text(0, 0, 'Jan'),
#   Text(1, 0, 'Feb'),
#   Text(2, 0, 'Mar'),
#   Text(3, 0, 'April'),
#   Text(4, 0, 'May'),
#   Text(5, 0, 'June'),
#   Text(6, 0, 'July'),
#   Text(7, 0, 'Aug'),
#   Text(8, 0, 'Sept'),
#   Text(9, 0, 'Oct'),
#   Text(10, 0, 'Nov'),
#   Text(11, 0, 'Dec')])
